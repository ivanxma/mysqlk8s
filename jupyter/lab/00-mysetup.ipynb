# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.6/31.6 MB 28.2 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
# ...

# %%
# !pip install sqlalchemy pandas ipython-sql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql

# %%
mypass = "mysql+mysqlconnector://myuser1:Password#1234@10.0.1.47/hkdb1"
# %sql  $mypass

# %%
# %%sql
# show databases;
# Out:
#    mysql+mysqlconnector://admin:***@10.0.1.47/hkdb1
#    mysql+mysqlconnector://admin:***@10.0.1.47/mysql
#  * mysql+mysqlconnector://myuser1:***@10.0.1.47/hkdb1
# 6 rows affected.
# [('airportdb',),
#  ('heatwaveml_bench',),
#  ('hkdb1',),
#  ('information_schema',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %%sql
# use airportdb;
# show tables;
# select * from airline;
# Out:
#    mysql+mysqlconnector://admin:***@10.0.1.47/hkdb1
#    mysql+mysqlconnector://admin:***@10.0.1.47/mysql
#  * mysql+mysqlconnector://myuser1:***@10.0.1.47/hkdb1
# 0 rows affected.
# 15 rows affected.
# 113 rows affected.
# [(1, 'AF', 'Afghanistan Airlines', 850),
#  (2, 'AL', 'Albania Airlines', 10274),
#  (3, 'AM', 'American Samoa Airli', 9210),
#  (4, 'AN', 'Angola Airlines', 190),
#  (5, 'AR', 'Argentina Airlines', 285),
#  (6, 'AU', 'Australia Airlines', 73),
#  (7, 'AZ', 'Azerbaijan Airlines', 1216),
#  (8, 'BA', 'Bahamas Airlines', 405),
#  (9, 'BE', 'Belarus Airlines', 1534),
#  (10, 'BH', 'Bhutan Airlines', 9320),
#  (11, 'BO', 'Bolivia Airlines', 466),
#  (12, 'BR', 'Brazil Airlines', 93),
#  (13, 'BU', 'Bulgaria Airlines', 1674),
#  (14, 'CA', 'Caicos Is Airlines', 2600),
#  (15, 'CE', 'Central African Rep ', 813),
#  (16, 'CH', 'Chad Airlines', 27),
#  (17, 'CO', 'Colombia Airlines', 118),
#  (18, 'CR', 'Croatia Airlines', 2373),
#  (19, 'CU', 'Cuba Airlines', 28),
# ...
